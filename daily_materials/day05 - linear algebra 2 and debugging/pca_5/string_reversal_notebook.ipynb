# %% [markdown]
# If you're using a Jupyter notebook, [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) has a built-in debugger that can be used to step through notebooks in a manner similar to the way that [pdb](https://docs.python.org/3/library/pdb.html) works in a command line Python interpreter.  Take a look at the [JupyterLab debugger documentation](https://jupyterlab.readthedocs.io/en/stable/user/debugger.html) and try it with this notebook, which has the same code as the broken `string_reversal.py` file.  Try putting in breakpoints at various places in the function (for example, within the loop), and look what the variables do!
#
# This is a simple (broken) program to reverse a string.  Look for 'BUG' to find the bug.
#
# Takes in a string of arbitrary (but assumed to be non-zero) length; returns a string of the same length, but reversed.

# %%
def reverse_string(mystring):
    '''
    Reverses the ordering of characters in a string using a simple loop.
    Input: a string.
    Output: a completely reversed version of that string, including all characters.
    '''
    
    reversed_string = ""

    if len(mystring)==0:
        return []

    '''
    Put a pdb breakpoint here and then step through the loop, printing out i,
    mystring[i], and reversed_string at each step - do you see where the loop
    breaks?
    '''
    
    # BUG: the 0 in the range() method should be -1, given how range() works!
    for i in range(len(mystring)-1,0,-1):  
        
        reversed_string += mystring[i]

    '''
    put a breakpoint here to see what the function is returning, as well as
    the final value of i.  Change range() and then re-run the code to
    see how these variables change!
    '''
    
    return reversed_string

# %%
mystring = "Go green!"

print("\noriginal string:    ",mystring,"\n")

# %%
reversed = reverse_string(mystring)

# this SHOULD say "!neerg oG" (without the quotes)
print("reversed string:    ",reversed,"\n")
