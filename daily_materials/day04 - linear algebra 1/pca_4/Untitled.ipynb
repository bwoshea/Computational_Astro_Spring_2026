# %%
V0 = 100.
R0 = 100.
R1 = R2 = 50.
R3 = 75.

# %%
Req = 1.0 / (1./R1 + 1./R2 + 1./R3)

# %%
I0 = V0 / (R0 + Req)

# %%
print(V0, I0)
# Out:
# 100.0 0.8421052631578947

# %%
V123 = V0 - I0*R0

# %%
print(V123)
# Out:
# 15.789473684210535

# %%
I1 = V123/R1
I2 = V123/R2
I3 = V123/R3

# %%
print(I1, I2, I3)
# Out:
# 0.3157894736842107 0.3157894736842107 0.21052631578947378
