# %%
redshifts = [10.3, 11.1, 12.2]
redshifts.reverse()

halo_number = 1

# %%
str(redshifts[0])

# %%
filenum = 0


for thisz in redshifts:
    filename = 'Cat_' + str(halo_number) + '_' + str(filenum) + '.csv'
    print(filename, thisz)
    filenum += 1
